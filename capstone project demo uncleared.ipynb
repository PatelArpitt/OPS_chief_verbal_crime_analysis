# %%
import PyPDF2
with open("Verbal 28Sep15.docx.pdf", "rb") as file:
#with open("Verbal.docx.pdf", "rb") as file:
#with open("2- Chiefs Final Verbal.docx.pdf", "rb") as file:

#with open("verbal report October2016.docx.pdf", "rb") as file:    
    # Create a PDF object
    pdf = PyPDF2.PdfReader(file)
    
    # Initialize a variable to store the extracted text
    corpus = ""
    
    # Extract the text from each page of the PDF. We have only one page.
    for page in pdf.pages:
        corpus += page.extract_text()
        
    # Print the extracted text
    print(corpus)
# Out:
# 1
#  Ottawa Police Services Board
# September 28 , 2015
# Chief’s Verbal Report
# Good evening,
# I have a number of items to update the Board on.
# Wilno  homicides
# Last week, our Service assisted a strong policing partner, the OPP , with the arrest of a
# 57-year-old male  suspect wanted  in connection with the tragic murder of 3 women near
# Wilno , Ontario .  We were alerted the suspect was possibly headed to the Ottawa area.
# Our officers located and arrested the  armed  suspect in the Kinburn area.  These events
# highlight the important work that still needs to continue to take place to end violence
# against women.
# Stabbing Death on Jasmine Cres
# On September 20, a 17 -year-old male victim was stabbed to death on Jasmine
# Crescent.   Thanks to the great wo rk of the responding officers and the Major Crime
# investigators, an 18 year old male and a 25 year old male, both of Ottawa, have been
# arrested and charged with 2nd Degree murder.
# Incident in the ByWard Market
# A number of our officers were also recently in volved in a violent encounter in the
# ByWard Market that resulted in two arrests and an OPS officer being injured.   On
# September 11, an Ottawa Police officer along with a civilian member of our Imaging
# Services Unit, were in a marked police cruiser at Willi am and York streets when a man
# stepped out in fron t of the cruiser blocking it.   The man became aggressive with the
# officer an d then assaulted the officer.   The civilian member observed the officer being
# assaulted and called for assistance on the police ra dio.  The officer attempted to place
# the male suspect under arrest and a physical confrontation ensued.  The suspect
# disarmed the officer of his baton and attempted to hit the officer with it.   Several other
# officers then responded to the scene to assist.   The first responding officer was also
# assaulted and had his baton  knocked away.  Officers were then able to arrest the 2
#  suspect. Shortly after this arrest a second male, wh o was unrelated to thi s matter,  made
# threats to officers and was arrested.
# I want to thank all the members – from Patrol, Imaging Services, NHO, and
# Communications -- involved for their response to this incident and for their
# professionalism in dealing with this individual.  This incident reminds us that harm to our
# officers can come quickly and without warning.
# Successful Investigations
# I’d also like to bring the Board’s attention to a number of longer term investigations that
# recently saw some success.
#  Man charged in relati on to 7 robberies
# Between July 23 and September 18, a series of convenience store robberies
# took place in Kanata.   Shortly after a robbery on September 18, a 30 -year-old
# male suspect was arrested a short distance away.   He was later linked to 6 other
# robberies and charged.
#  Man charged in series of thefts
# As well, o n September 14, our Patrol officers were called to a store in Westboro
# for a theft in progress.   The male suspect was arrested.   It was later determined
# the suspect  was linked to  43 other theft incidents across Canada, including
# British Columbia, Alberta, Saskatchewan, Manitoba, and Ontario.   We have since
# been in contact with the police agencies in the other jurisdictions  to notify them of
# the arrest.   Had it not been for the great communicat ion between agencies,
# including loss prevention, this arrest and the subsequent linkages would not have
# been possible .
#  Joint Organized Auto Theft Investigation
# In the winter of 2014, our Organized Auto Theft Section started a joint
# investigation with the Service de la sécurité publique de la MRC des Collines into
# vehicles being stolen from Ontario and Quebec and later given new vehicle
# identification numbers (VIN) before being registered in Ontario and sold.  The
# investigation was successfully concluded th is past August and resulted in four
# arrests, the seizure of 26 vehicles, and a total of 49 charges being laid.   I am also
# proud to mention that in October, our Organized Auto Theft Section  will be 3
#  awarded the Vehicle Theft Award of Merit by the Internation al Association of
# Chiefs of Police in Chicago.   The award recognizes outstanding contributions to
# vehicle theft prevention and/or enforcement.
#  Human Trafficking Charges
# Following a four month long investigation  into organized prostitution and human
# trafficking operations by our Human Trafficking Unit , a man has been charged
# with 76 criminal offences related to a total of 17 adult female victims.
#  Guilty Verdict in Parental Abduction
# Back in November of 2014, our Service became involved in an investigation into
# an attempted  parental abduction involving 4 young children.   A mother had
# conspired with her boyfriend to abduct her 4 children from her ex -common law
# husband and take them to Mexico City to start a new life .  When the father of the
# children came home to find their mother had fled with his children, he called 911.
# Our patrol officers quickly located the flight itinerary and liaised  with the Peel
# Regional  Police Service to locate the mother and children at th e airport, and
# disembark them from a plane that was set to leave a mere 10 minutes later.
# Following the arrest of the mother, an extensive investigation began that led to
# the mother being charged with a number of criminal charges including Parental
# Abduction without  a Court Order .  She was  found guilty on all counts this past
# September.   The successful outcome of this investigation would not have been
# possible without the great  team effort  between the officers and investigators at
# our Service, our Vict im Crisis Unit, the  Peel Regional Police, the Crown’s office,
# and the Victim/Witness Assistance Program.
# These investigations are not only long, they are also difficult and require a lot of hard
# work and patience on the part of all those involved.
# Taxi S trike
# A recent injunction was  granted the City of Ottawa that limits the size and scope of the
# ongoing protests by taxi drivers. The injunction also prohibits blocking and hinder ing
# traffic on Airport roadways unless the union has been granted a permit by the city.   We
# continue  to monitor the Airport Taxi labour dispute and work with strike organizers, the
# employer, and stakeholders.   From the beginning, our priority has been to ensure public
# safety and road access while balancing the right to demonstrate.   Where warranted, we 4
#  have launched investigations  and laid charges  into unlawful activities, including reports
# of vandalism  and mischief.   We continue to monitor the situation and intervene as
# required.
# Guns & Gangs Update
# The issue of guns and gangs in ou r community continues to be a priority.   Just last
# weekend, two individuals were charged with attempted murder along with multiple
# firearm and assault related offences, following an incident on Montreal Road where they
# tried to discharge a loaded firearm o n two victims.  Enforcement is taking place every
# day in our community.
# To date:
#  59 seized guns have been taken off the street;
#  250 people associated with gang activity have been charged, and,
#  1,218 criminal charges have been laid against those people.
# In addition to enforcement, our approach  continues  to include  community involvement
# and strategies aimed at preventing young people from joining gangs .
# City-Wide School Zone Enforcement
# Our Traffic Sections, assisted by School Resource Officers and Patrol officers,
# conducted city -wide proactive traffic enforcement blitzes in school zones.  A two -
# enforcement campaign was held September 8 and 9 focusing on:
#  speeding in school zones;
#  failing to stop or yield to pedestrians at school crossings;
#  failing to obey crossing guards;
#  failing to obey school bus signs; and
#  distracted driving.
# A total of 142 Provincial Offence Notices were issued during this enforcement
# campaign.   5
#  Award of Order of Merit of the Police Forces
# I’d like to recognize a few of our members who were recently invested into the Order of
# Merit of the Police Forces by His Excellency the Right Honourable David Johnston,
# Governor General of Canada.   The award recognizes except ional merit and service by
# members and employees of Canadian police forces whose contributions extend beyond
# protection of the community.   A big congratulations goes out to Staff  Sergeant Rob
# Bernier, Staff Sergeant Isobel Granger and Inspector Chris Renwi ck who were all
# invested  in a ceremony at Rideau Hall on September 16.
# Canadian Police & Peace Officers' Memorial Service
# And finally, t his past Sunday marked the 38th Annual Canadian Police & Peace Officers’
# Memorial Service.   The Service is a means of ho nouring fallen officers and ensuring
# their ultimate sacrifice is never forgotten.   Sadly, four names were added to the
# Memorial this year.   I would like to thank all those who participated in the Memorial
# Service, including Board members. In addition, I want to recognize the 11 Ottawa Police
# members  who ran in the Run to Remember and the 12 cyclists who cycled in the Ride
# to Remember leading up to the service.   A special thank you to Acting Staff Sergeant
# Alison Coo kson for her work in helping to coordinate the run for our Service.
# That concludes my update.
# Thank you.

# %%
# import PyPDF2

# with open("2- Chiefs Final Verbal.docx.pdf") as file:
#     # Create a PDF object
#     pdf = PyPDF2.PdfReader(file)
    
#     # Initialize a variable to store the extracted text
#     corpus = ""
    
#     # Extract the text from each page of the PDF. We have only one page.
#     for page in pdf.pages:
#         corpus += page.extract_text()
        
#     # Print the extracted text
#     #corpus = corpus.lower()
#     print(corpus)

# %%
import nltk

corpus = corpus.replace("\n"," ")
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
sentences = tokenizer.tokenize(corpus)
print(sentences)
# Out:
# ['1   Ottawa Police Services Board   September 28 , 2015   Chief’s Verbal Report   Good evening,   I have a number of items to update the Board on.', 'Wilno  homicides   Last week, our Service assisted a strong policing partner, the OPP , with the arrest of a  57-year-old male  suspect wanted  in connection with the tragic murder of 3 women near   Wilno , Ontario .', 'We were alerted the suspect was possibly headed to the Ottawa area.', 'Our officers located and arrested the  armed  suspect in the Kinburn area.', 'These events  highlight the important work that still needs to continue to take place to end violence  against women.', 'Stabbing Death on Jasmine Cres   On September 20, a 17 -year-old male victim was stabbed to death on Jasmine  Crescent.', 'Thanks to the great wo rk of the responding officers and the Major Crime  investigators, an 18 year old male and a 25 year old male, both of Ottawa, have been  arrested and charged with 2nd Degree murder.', 'Incident in the ByWard Market   A number of our officers were also recently in volved in a violent encounter in the  ByWard Market that resulted in two arrests and an OPS officer being injured.', 'On  September 11, an Ottawa Police officer along with a civilian member of our Imaging  Services Unit, were in a marked police cruiser at Willi am and York streets when a man  stepped out in fron t of the cruiser blocking it.', 'The man became aggressive with the  officer an d then assaulted the officer.', 'The civilian member observed the officer being  assaulted and called for assistance on the police ra dio.', 'The officer attempted to place  the male suspect under arrest and a physical confrontation ensued.', 'The suspect  disarmed the officer of his baton and attempted to hit the officer with it.', 'Several other  officers then responded to the scene to assist.', 'The first responding officer was also  assaulted and had his baton  knocked away.', 'Officers were then able to arrest the 2   suspect.', 'Shortly after this arrest a second male, wh o was unrelated to thi s matter,  made  threats to officers and was arrested.', 'I want to thank all the members – from Patrol, Imaging Services, NHO, and  Communications -- involved for their response to this incident and for their  professionalism in dealing with this individual.', 'This incident reminds us that harm to our  officers can come quickly and without warning.', 'Successful Investigations   I’d also like to bring the Board’s attention to a number of longer term investigations that  recently saw some success.', '\uf0b7 Man charged in relati on to 7 robberies   Between July 23 and September 18, a series of convenience store robberies  took place in Kanata.', 'Shortly after a robbery on September 18, a 30 -year-old  male suspect was arrested a short distance away.', 'He was later linked to 6 other  robberies and charged.', '\uf0b7 Man charged in series of thefts   As well, o n September 14, our Patrol officers were called to a store in Westboro  for a theft in progress.', 'The male suspect was arrested.', 'It was later determined  the suspect  was linked to  43 other theft incidents across Canada, including  British Columbia, Alberta, Saskatchewan, Manitoba, and Ontario.', 'We have since  been in contact with the police agencies in the other jurisdictions  to notify them of  the arrest.', 'Had it not been for the great communicat ion between agencies,  including loss prevention, this arrest and the subsequent linkages would not have  been possible .', '\uf0b7 Joint Organized Auto Theft Investigation   In the winter of 2014, our Organized Auto Theft Section started a joint  investigation with the Service de la sécurité publique de la MRC des Collines into  vehicles being stolen from Ontario and Quebec and later given new vehicle  identification numbers (VIN) before being registered in Ontario and sold.', 'The  investigation was successfully concluded th is past August and resulted in four  arrests, the seizure of 26 vehicles, a ...

# %%
import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()
crime = []
not_crime = []

# Loop through the sentences and determine the sentiment score
for sentence in sentences:
    # Get the sentiment score for the sentence
    sentiment_score = analyzer.polarity_scores(sentence)
    
    # Determine if the sentence has a negative sentiment (indicating a crime)
    if sentiment_score['neg'] > sentiment_score['pos']:
        crime.append(sentence)
        
    else:
        not_crime.append(sentence)
print(crime)
# Out:
# ['Wilno  homicides   Last week, our Service assisted a strong policing partner, the OPP , with the arrest of a  57-year-old male  suspect wanted  in connection with the tragic murder of 3 women near   Wilno , Ontario .', 'We were alerted the suspect was possibly headed to the Ottawa area.', 'Our officers located and arrested the  armed  suspect in the Kinburn area.', 'Stabbing Death on Jasmine Cres   On September 20, a 17 -year-old male victim was stabbed to death on Jasmine  Crescent.', 'Thanks to the great wo rk of the responding officers and the Major Crime  investigators, an 18 year old male and a 25 year old male, both of Ottawa, have been  arrested and charged with 2nd Degree murder.', 'Incident in the ByWard Market   A number of our officers were also recently in volved in a violent encounter in the  ByWard Market that resulted in two arrests and an OPS officer being injured.', 'On  September 11, an Ottawa Police officer along with a civilian member of our Imaging  Services Unit, were in a marked police cruiser at Willi am and York streets when a man  stepped out in fron t of the cruiser blocking it.', 'The man became aggressive with the  officer an d then assaulted the officer.', 'The civilian member observed the officer being  assaulted and called for assistance on the police ra dio.', 'The officer attempted to place  the male suspect under arrest and a physical confrontation ensued.', 'The suspect  disarmed the officer of his baton and attempted to hit the officer with it.', 'The first responding officer was also  assaulted and had his baton  knocked away.', 'Officers were then able to arrest the 2   suspect.', 'Shortly after this arrest a second male, wh o was unrelated to thi s matter,  made  threats to officers and was arrested.', 'This incident reminds us that harm to our  officers can come quickly and without warning.', '\uf0b7 Man charged in relati on to 7 robberies   Between July 23 and September 18, a series of convenience store robberies  took place in Kanata.', 'Shortly after a robbery on September 18, a 30 -year-old  male suspect was arrested a short distance away.', 'He was later linked to 6 other  robberies and charged.', 'The male suspect was arrested.', 'We have since  been in contact with the police agencies in the other jurisdictions  to notify them of  the arrest.', 'Had it not been for the great communicat ion between agencies,  including loss prevention, this arrest and the subsequent linkages would not have  been possible .', '\uf0b7 Joint Organized Auto Theft Investigation   In the winter of 2014, our Organized Auto Theft Section started a joint  investigation with the Service de la sécurité publique de la MRC des Collines into  vehicles being stolen from Ontario and Quebec and later given new vehicle  identification numbers (VIN) before being registered in Ontario and sold.', 'The  investigation was successfully concluded th is past August and resulted in four  arrests, the seizure of 26 vehicles, and a total of 49 charges being laid.', '\uf0b7 Human Trafficking Charges   Following a four month long investigation  into organized prostitution and human  trafficking operations by our Human Trafficking Unit , a man has been charged  with 76 criminal offences related to a total of 17 adult female victims.', '\uf0b7 Guilty Verdict in Parental Abduction   Back in November of 2014, our Service became involved in an investigation into  an attempted  parental abduction involving 4 young children.', 'Our patrol officers quickly located the flight itinerary and liaised  with the Peel  Regional  Police Service to locate the mother and children at th e airport, and  disembark them from a plane that was set to leave a mere 10 minutes later.', 'Following the arrest of the mother, an extensive investigation began that led to  the mother being charged with a number of criminal charges including Parental  Abduction without  a Court Order .', 'She was  found guilty on all counts this past  September.', 'The succe ...

# %%
import pandas as pd
df = pd.DataFrame({'sentences': crime})

# %%
print(df)
# Out:
#                                             sentences
# 0   Wilno  homicides   Last week, our Service assi...
# 1   We were alerted the suspect was possibly heade...
# 2   Our officers located and arrested the  armed  ...
# 3   Stabbing Death on Jasmine Cres   On September ...
# 4   Thanks to the great wo rk of the responding of...
# 5   Incident in the ByWard Market   A number of ou...
# 6   On  September 11, an Ottawa Police officer alo...
# 7   The man became aggressive with the  officer an...
# 8   The civilian member observed the officer being...
# 9   The officer attempted to place  the male suspe...
# 10  The suspect  disarmed the officer of his baton...
# 11  The first responding officer was also  assault...
# 12  Officers were then able to arrest the 2   susp...
# 13  Shortly after this arrest a second male, wh o ...
# 14  This incident reminds us that harm to our  off...
# 15   Man charged in relati on to 7 robberies   Be...
# 16  Shortly after a robbery on September 18, a 30 ...
# 17  He was later linked to 6 other  robberies and ...
# 18                     The male suspect was arrested.
# 19  We have since  been in contact with the police...
# 20  Had it not been for the great communicat ion b...
# 21   Joint Organized Auto Theft Investigation   I...
# 22  The  investigation was successfully concluded ...
# 23   Human Trafficking Charges   Following a four...
# 24   Guilty Verdict in Parental Abduction   Back ...
# 25  Our patrol officers quickly located the flight...
# 26  Following the arrest of the mother, an extensi...
# 27  She was  found guilty on all counts this past ...
# 28  The successful outcome of this investigation w...
# 29  These investigations are not only long, they a...
# 30  The injunction also prohibits blocking and hin...
# 31  We  continue  to monitor the Airport Taxi labo...
# 32  Where warranted, we 4   have launched investig...
# 33  Just last  weekend, two individuals were charg...
# 34  To date:    59 seized guns have been taken of...
# 35  In addition to enforcement, our approach  cont...
# 36  A two - enforcement campaign was held Septembe...
# 37  A total of 142 Provincial Offence Notices were...
# 38  Sadly, four names were added to the  Memorial ...

# %%
import spacy
import pandas as pd
import re

# load the pre-trained model
nlp = spacy.load("en_core_web_sm")

# example DataFrame

df2 = pd.DataFrame(df)

# function to detect if a sentence contains a crime
def contains_crime(sentence):
    # apply NER to the sentence
    doc = nlp(sentence)
    # check for entities labelled as "CRIME" or "LAW"
    for ent in doc.ents:
        
        if ent.label_ in ['CRIME', 'LAW', 'MURDER', 'PERSON', 'WEAPON', 'MONEY','GUN','CRIMINAL CHARGES','NUMBERS']:
            return True
    # check for POS tags indicating a violent crime
    for token in doc:
        if token.pos_ == 'VERB' and token.lemma_ in ['homicides','murder','kill','sexual' ,'murder', 'assault','drug','shotgun','rob','CRIMINAL','charges' ,'rape','violence','attack','sexual assault','robbery','shoot','GUN']:
            return True
    return False

# apply the function to the DataFrame
df2['contains_crime'] = df2['sentences'].apply(contains_crime)

print(df2)
# Out:
#                                             sentences  contains_crime
# 0   Wilno  homicides   Last week, our Service assi...            True
# 1   We were alerted the suspect was possibly heade...           False
# 2   Our officers located and arrested the  armed  ...           False
# 3   Stabbing Death on Jasmine Cres   On September ...            True
# 4   Thanks to the great wo rk of the responding of...           False
# 5   Incident in the ByWard Market   A number of ou...            True
# 6   On  September 11, an Ottawa Police officer alo...            True
# 7   The man became aggressive with the  officer an...            True
# 8   The civilian member observed the officer being...            True
# 9   The officer attempted to place  the male suspe...           False
# 10  The suspect  disarmed the officer of his baton...           False
# 11  The first responding officer was also  assault...           False
# 12  Officers were then able to arrest the 2   susp...           False
# 13  Shortly after this arrest a second male, wh o ...           False
# 14  This incident reminds us that harm to our  off...           False
# 15   Man charged in relati on to 7 robberies   Be...           False
# 16  Shortly after a robbery on September 18, a 30 ...           False
# 17  He was later linked to 6 other  robberies and ...           False
# 18                     The male suspect was arrested.           False
# 19  We have since  been in contact with the police...           False
# 20  Had it not been for the great communicat ion b...           False
# 21   Joint Organized Auto Theft Investigation   I...            True
# 22  The  investigation was successfully concluded ...           False
# 23   Human Trafficking Charges   Following a four...           False
# 24   Guilty Verdict in Parental Abduction   Back ...           False
# 25  Our patrol officers quickly located the flight...           False
# 26  Following the arrest of the mother, an extensi...           False
# 27  She was  found guilty on all counts this past ...           False
# 28  The successful outcome of this investigation w...           False
# 29  These investigations are not only long, they a...           False
# 30  The injunction also prohibits blocking and hin...           False
# 31  We  continue  to monitor the Airport Taxi labo...           False
# 32  Where warranted, we 4   have launched investig...           False
# 33  Just last  weekend, two individuals were charg...            True
# 34  To date:    59 seized guns have been taken of...           False
# 35  In addition to enforcement, our approach  cont...           False
# 36  A two - enforcement campaign was held Septembe...           False
# 37  A total of 142 Provincial Offence Notices were...           False
# 38  Sadly, four names were added to the  Memorial ...           False

# %%
df3 = df2[df2['contains_crime'] == True]
print(df3)
import numpy as np
# Out:
#                                             sentences  contains_crime
# 0   Wilno  homicides   Last week, our Service assi...            True
# 3   Stabbing Death on Jasmine Cres   On September ...            True
# 5   Incident in the ByWard Market   A number of ou...            True
# 6   On  September 11, an Ottawa Police officer alo...            True
# 7   The man became aggressive with the  officer an...            True
# 8   The civilian member observed the officer being...            True
# 21   Joint Organized Auto Theft Investigation   I...            True
# 33  Just last  weekend, two individuals were charg...            True

# %%
pd.options.mode.chained_assignment = None

homicide_regex = re.compile(r"(murder|killing|death|homicide|manslaughter|Guns)", re.IGNORECASE)
stabbing_regex = re.compile(r"(stabbing|knife attack)", re.IGNORECASE)
police_regex = re.compile(r"(violance|violent| encounter|police officer|injured|assaulted the officer|constable)", re.IGNORECASE)
stolen_regex = re.compile(r"(Theft|stolen)", re.IGNORECASE)
drug_regex = re.compile(r"(drug|marijuana|substances)", re.IGNORECASE)
driving_regex = re.compile(r"(stunt|driving)", re.IGNORECASE)



# Define a function to detect the type of crime in a sentence
def detect_crime_type(sentence):
    if re.search(homicide_regex, sentence):
        return "Homicide"
    elif re.search(stabbing_regex, sentence):
        return "Stabbing"
    elif re.search(police_regex, sentence):
        return "Total assaults against a peace officer"
    elif re.search(stolen_regex, sentence):
        return "Total possession of stolen property"
    elif re.search(drug_regex, sentence):
        return "drug violations"
    elif re.search(driving_regex, sentence):
        return " traffic violations"
    else:
        return "Unknown"
def detect_num_people(text):
    pattern = r"\b(\d+|one|two|three|four|five|six|seven|eight|nine|ten)\b(?=\s*(?:for\s)?(?:criminals?|arrests?|suspects?|offenders?|men|people|individuals|stunt))"
    match = re.search(pattern, text)
    if match:
        num_str = match.group(1)
        if num_str.isdigit():
            num = int(num_str)
            if num > 100: # Assume it's an age
                return None
            elif num >= 10 and 'old' in text: # Assume it's an age
                return None
            else:
                return num
        elif num_str == 'one':
            return 1
        elif num_str == 'two':
            return 2
        elif num_str == 'three':
            return 3
        elif num_str == 'four':
            return 4
        elif num_str == 'five':
            return 5
        elif num_str == 'six':
            return 6
        elif num_str == 'seven':
            return 7
        elif num_str == 'eight':
            return 8
        elif num_str == 'nine':
            return 9
        elif num_str == 'ten':
            return 10
    else:
        return None








#df3["num_people"] = df3["sentences"].apply(detect_num_people).replace(np.nan, 1).astype(int)
df3.loc[:, "num_people_involved"] = df3["sentences"].apply(detect_num_people).replace(np.nan, 1).astype(int)
df3.loc[:, "crime_type"] = df3["sentences"].apply(detect_crime_type)



    

# Add a new column to the DataFrame with the detected crime type
#df3.loc[:, "crime_type"] = df3["sentences"].apply(detect_crime_type)


# Print the modified DataFrame
print(df3)
# Out:
#                                             sentences  contains_crime  \
# 0   Wilno  homicides   Last week, our Service assi...            True
# 3   Stabbing Death on Jasmine Cres   On September ...            True
# 5   Incident in the ByWard Market   A number of ou...            True
# 6   On  September 11, an Ottawa Police officer alo...            True
# 7   The man became aggressive with the  officer an...            True
# 8   The civilian member observed the officer being...            True
# 21   Joint Organized Auto Theft Investigation   I...            True
# 33  Just last  weekend, two individuals were charg...            True
#
#     num_people_involved                              crime_type
# 0                     1                                Homicide
# 3                     1                                Homicide
# 5                     2  Total assaults against a peace officer
# 6                     1  Total assaults against a peace officer
# 7                     1  Total assaults against a peace officer
# 8                     1                                 Unknown
# 21                    1     Total possession of stolen property
# 33                    2                                Homicide

# %%
print(df3)
output_path = 'output2.xlsx'
df3.to_excel(output_path, index=False)
# Out:
#                                             sentences  contains_crime  \
# 0   Wilno  homicides   Last week, our Service assi...            True
# 3   Stabbing Death on Jasmine Cres   On September ...            True
# 5   Incident in the ByWard Market   A number of ou...            True
# 6   On  September 11, an Ottawa Police officer alo...            True
# 7   The man became aggressive with the  officer an...            True
# 8   The civilian member observed the officer being...            True
# 21   Joint Organized Auto Theft Investigation   I...            True
# 33  Just last  weekend, two individuals were charg...            True
#
#     num_people_involved                              crime_type
# 0                     1                                Homicide
# 3                     1                                Homicide
# 5                     2  Total assaults against a peace officer
# 6                     1  Total assaults against a peace officer
# 7                     1  Total assaults against a peace officer
# 8                     1                                 Unknown
# 21                    1     Total possession of stolen property
# 33                    2                                Homicide
